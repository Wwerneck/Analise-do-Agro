# %% [markdown]
# # 04 Business Analysis
# Analise de participacao, crescimento e decomposicao.

# %%
import pandas as pd
produtos = pd.read_csv('../../data/processed/conab_produtos_clean.csv')
cols = ['produto','producao_atual_mil_t','participacao_producao_pct','variacao_producao_pct_calc','classificacao_decomposicao']
produtos.query("tipo_linha == 'produto'")[cols].sort_values('producao_atual_mil_t', ascending=False).head(15)
