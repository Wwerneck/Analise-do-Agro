# %% [markdown]
# # 03 EDA
# Ranking de produtos e UFs sem misturar linhas agregadas.

# %%
import pandas as pd
produtos = pd.read_csv('../../data/processed/conab_produtos_clean.csv')
ufs = pd.read_csv('../../data/processed/conab_ufs_clean.csv')
produtos.query("tipo_linha == 'produto'").sort_values('producao_atual_mil_t', ascending=False).head(10)

# %%
ufs.query("tipo_linha == 'uf'").sort_values('producao_atual_mil_t', ascending=False).head(10)
