# %% [markdown]
# # 02 Data Cleaning
# Carrega bases processadas para inspecao dos tratamentos.

# %%
import pandas as pd
produtos = pd.read_csv('../../data/processed/conab_produtos_clean.csv')
ufs = pd.read_csv('../../data/processed/conab_ufs_clean.csv')
produtos.head(), ufs.head()
